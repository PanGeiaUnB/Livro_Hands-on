# %%
import math
import time
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import random
from collections import namedtuple
from itertools import count
import torch
import torch.nn as nn
import csv
import os
import pandas as pd
import gym

# %%
env = gym.make('Pendulum-v0') #Construção do ambiente do pendulo
#env = gym.make('MountainCarContinuous-v0') #Construção do ambiente do mountain car

# %%
def testar_gpu():
    '''
    Função que testa se a GPU está habilitada.
    
    Outputs:
    --------
    device: {str}
        variável que define se o código será executado na CPU ou na GPU
    '''
    train_on_gpu = torch.cuda.is_available() #Observa se a GPU está disponivel
    if train_on_gpu: #Se sim
        device = torch.device('cuda') #Seleciona o device como GPU
        print("Treinando na GPU") #E manda a mensagem
    else: #Se não
        device = torch.device('cpu') #Seleciona o device como cpu
        print("GPU indisponível, treinando na CPU") #E avisa que a GPU não esta disponível
    
    return device

# %%
#Coleta onde o ambiente será executado
device = testar_gpu()

#Define uma transição como um tupla com estado, ação, próximo estado e recompensa.
Transition = namedtuple('Transition',
                        ('state', 'action', 'next_state', 'reward'))
# Out:
# Treinando na GPU

# %% [markdown]
# A última lição mostrou uma implementação de uma *Deep Q-Network*, a rede mais básica de DRL, que nos permitiu elaborar um algoritmo que conseguisse decidir quais ações devem ser tomadas pelo cartpole, para evitar que a haste caia.
#
# Entretanto, esse algoritmo apresenta uma clara limitação: ela só consegue resolver problemas em que as ações possíveis são **discretas**. Isso é perceptível ao perceber que a rede retorna apenas **qual** ação deve ser tomada, e não **como** ela deve ser executada. Passemos a um outro problema para que isso fique mais claro.
#
# Pense em um jogo parecido com o *cartpole*, mas agora nós queremos equilibrar um pêndulo verticalmente na posição mais alta possível. Para isso, nós podemos aplicar, no pêndulo, forças tanto no sentido horário como no anti-horário, em que as intensidades dessas forças são contínua, de forma que rotação pode ter mais ou menos intensidade, a depender da força aplicada.
#
# Assim, a rotação do pêndulo é controlada por um agente que define uma ação tal que $-2 < a < 2$, em que os valores negativos indicam que as forças são no sentido anti-horário e os positivos que são no sentido horário, enquanto o módulo do ação tal que $|a|<2$, indica a intensidade da força aplicada. A imagem abaixo mostra o pêndulo em vermelho e a representação da força aplicada como a seta preta.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Repare a ação desse ambiente é **contínua**, isto é, não basta o agente saber que precisa aplicar uma força em um ou outro sentido, ele precisa entender **o quanto** ele precisa colocar de intensidade na força.
#
# Voltemos, então, ao DQL. Para implementar uma DQN, neste caso, precisaríamos discretizar a intensidade da força e combiná-las com o sentido de rotação, considerando que cada uma dessas combinações seja uma ação possível com um $Q(s,a)$ calculável.
#
# Perceba que essa não é uma abordagem eficaz mesmo para um problema relativamente simples como esse. Identificando essa limitação, desenvolveu-se outra arquitetura que consegue ultrapassar essa barreira.

# %% [markdown]
# ## Redes do tipo Actor-Critic
#
# É importante ressaltar que o termo *Actor-critic* **não** designa uma arquitetura de DRL, e sim uma característica que várias arquiteturas da área incorporaram, entre elas o A2C, A3C e o DDPG. Nesse notebook, apresentaremos e utilizaremos o DDPG.
#
# Dizer que uma arquitetura é *actor-critic*, significa dizer que ela utiliza, pelo menos, **duas** redes neurais no seu processo de aprendizagem: uma que toma a ação e outra que critica a ação tomada, daí surge o nome *actor-critic*.
#
# A rede do ator recebe o estado como entrada e produz uma saída, podendo ser um número ou um vetor. Após a tomada de decisão do ator, o crítico vai estimar o valor de $Q(s,a)$ a partir do estado e dessa ação realizada, tentando avaliar se a ação tomada foi boa ou ruim.
#
# Assim, percebemos que essas arquiteturas desagregam o tomador de decisão e o estimador do $Q(s,a)$, de forma que a saída do ator pode ser de natureza contínua, cabendo ao crítico realizar a estimativa do retorno a partir dessa ação tomada. Entendido isso, precisamos entender como as duas redes aprendem.

# %% [markdown]
# ## Deep Deterministic Gradient Policy - DDPG
#
# Repare que o problema para o agente ainda é o mesmo: precisamos desenvolver um algoritmo capaz de maximizar o retorno. Nesse cenário, como treinar o ator?
#
# Como o $Q$ é uma estimativa do retorno recebido, é possível treinar o ator através da saída do crítico: se a saída deste for alta, o ator entenderá que agiu de maneira adequada, caso contrário, o ator terá que mudar a sua política de decisão de ação, modificando os seus parâmetros.
#
# Certo, mas como treinaremos o crítico para que ele consiga fazer estimativas de $Q(s,a)$ de maneira acurada, de forma que o ator possa "confiar" nessa estimativa para atualizar os seus pesos? A resposta é a mesma dada para o aprendizado da DQN, a partir da **Equação de Bellman**:
#
# $$ Q(s,a) = \mathbb{E}_{s'\mathtt{\sim}P}\{r_t + \mathbb{E}_{a'\mathtt{\sim}\mu}[Q(s',a')]\} $$
#
# Rememorando essa equação, ela nos mostra que o valor do par estado-ação atual pode ser estimado através do valor do par estado-ação futuro, somado a uma recompensa. Apesar de ambos os lados dependerem de estimativas do $Q$, o fato de não haver incerteza na medição da recompensa faz com que o lado direito da equação seja mais acurado, de forma que ele é tratado como o valor alvo para a otimização.
#
# Assim podemos resumir o processo de aprendizado utilizando a imagem abaixo. Na figura, as setas verdes significam a passagem de entradas e saídas até a estimativa dos dois lados da equação de Bellman e as setas vermelhas mostram o processo de atualização dos parâmetros das redes a partir dos custos calculados.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Na imagem acima, a função de custo do crítico ilustrada pode ser de diferentes naturezas. A mais clássica para identificar a diferença entre duas grandezas é o Erro Quadrático Médio (*Mean Squared Error* - MSE) e é ela que será utilizada.
#
# Para atualizar o ator, nós queremos promover o **aumento** do $Q(s',a')$ a cada ação executada, estimulando ações com alto valor do estado-ação. Pensando então no processo de aprendizado, sabemos que a maioria dos algoritmos se baseiam na **diminuição** do gradiente da perda, como adequar o problema?
#
# Uma solução é utilizar a perda como $-Q(s',a')$, de forma que, quanto maior o $Q$, menor a função de perda $-Q$ e, consequetemente, menor serão as atualizações dos parâmetros da ator. Em um caso contrário, a rede entenderá que as suas ações estão distantes do objetivo e que a política de tomada das ações deve ser modificada.
#
# Para entender mais sobre o processo de treinamento do DDPG, o pseudo-código pode ser encontrado neste [link](https://towardsdatascience.com/deep-deterministic-policy-gradients-explained-2d94655a9b7b).

# %% [markdown]
# ### Estratégias de treinamento do DDPG
#
# Como foi dito, o treinamento das arquiteturas de DRL é um processo instável e, por isso, adotam-se algumas técnicas para tentar diminuir essa instabilidade. Entre essas técnicas estão:
#
# *    Experience Replay
# *    Target Network
# *    Utilização de ruído nos parâmetros
#
# As duas primeiras estratégias já foram explicadas na última lição, mas a última não, então faremos uma breve introdução.

# %% [markdown]
# #### Ruído nos parâmetros para exploração
#
# Como foi visto, em problemas com ações discretas, é possível realizar a exploração do ambiente escolhendo algumas ações de maneira aleatória (utilizando a técniga do $\epsilon$-greedy, por exemplo). Já em problemas com ações contínuas, o mais comum é que se adicione ruído gaussiano na saída da rede neural, variando essas ações de maneira aleatória, como mostrado nessa [publicação](https://towardsdatascience.com/deep-deterministic-policy-gradients-explained-2d94655a9b7b), na seção "*Exploration*".
#
# Entretanto, recentemente surgiu uma nova abordagem para essa exploração. Propôs-se que, em vez de adicionar o mecanismo de exploração após o funcionamento da rede, é possível adicionar esse mecanismo **durante** a atuação da rede neural.
#
# A ideia é que nós adicionemos um ruído aleatório nos parâmetros da rede, alterando todos os pesos desta. Essa aleatoriedade garante que a rede tome ações diferentes mesmo em situações parecidas, trazendo a ideia de exploração. Essa [tese de mestrado](https://matthiasplappert.com/publications/2017_Plappert_Master-thesis.pdf) abordou o assunto de forma bastante simples e completa. Será essa a estratégia utilizada no nosso código.
#
# Basicamente, a proposta é, a cada episódio, contaminar os parâmetros da rede neural com amostras de um ruído gaussiano de média 0 e desvio padrão $\sigma$. Essas amostras são geradas aleatoriamente a cada episódio, respeitando a distribuição gaussiana em questão. A imagem abaixo, retirada da tese citada acima, ilustra a diferença entre o ruído na ação e o ruído nos parâmetros.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Essa estratégia também é adaptativa, isto é, ela muda as configurações dos parâmetros de ruído, para aumentar ou diminuir o efeito explorativo. De maneira prática, com o passar dos episódios, o desvio padrão $\sigma$ do ruído é modificado, aumentando o seu valor quando se deseja aumentar a exploração e diminuindo o seu valor quando se deseja diminuir a exploração.
#
# Essa decisão é feita analisando se a diferença entre as decisões feitas com e sem ruído é maior do que um certo limiar de decisão $\delta$, de forma que, se for maior, o $\sigma$ deve ser diminuido, se for menor, o $\sigma$ deve ser aumentado. A diferença entre essas ações ruidosas e limpas geralmente é calculada utilizando o Erro Quadrático Médio, como mostrado na imagem abaixo com a função $d(\cdot,\cdot)$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Dessa forma, a adaptação no parâmetro $\sigma$ é feita a partir de um certo $\alpha$ maior que $1$, geralmente com um valor ligeiramente maior do que 1. Essa adaptação é feita a partir do equacionamento abaixo:
#
# $$ \sigma_{t+1} = \left\{\begin{array}{ll}
# \alpha \sigma_t, \:\:\:\: d(\pi(a|s), \tilde{\pi}(a|s)) \leq \delta \\
# \frac{1}{\alpha} \sigma_t,\:\:\:\: cc \\
# \end{array} \right. $$
#
# em que $d(\cdot,\cdot)$ é uma função de cálculo de distância entre vetores, $\pi(a|s)$ são as ações determinadas pela rede não contaminada com ruído, $\tilde{\pi}(a|s)$ são as ações determinadas pela rede com o ruído nor parâmetros, $\delta$ é o limiar de decisão de adaptação e $\alpha$ é o parâmetro de adaptação.
#
# Na prática, nós criamos uma outra rede neural auxiliar que será sempre uma cópia da rede neural do agente, mas com os parâmetros contaminados, e utilizamos ela para a tomada de decisões no processo de treinamento. Entretanto, na hora de otimizar as redes, o algoritmo otimiza a rede neural **não** contaminada, atualizando seus parâmetros e copiando-os novamente nessa rede auxiliar, que será novamente contaminada com um ruído aleatório para o próximo episódio.
#
# Seguindo esse processo e o equacionamento mostrado, o algoritmo atualiza o valor de $\sigma$ do ruído a cada $T_{adapt}$ episódios, garantindo uma exploração mais inteligente e duradoura.

# %% [markdown]
# A partir do que foi explanado acima, podemos partir pra implementação do nosso código

# %% [markdown]
# ## Implementação do algoritmo

# %% [markdown]
# Iniciaremos o problema implementando a memória do *replay buffer*. A implementação será a mesma utilizada na última lição.

# %%
class ReplayMemory(object):
    def __init__(self, capacity):
        '''
        Classe que define a memória do Replay Buffer
        
        Parâmetros:
        -----------
        capacity: {int}
            número de elementos que podem ser armazenados na memória.
        '''
        self.capacity = capacity
        self.memory = []
        self.position = 0

    def push(self, *args):
        '''
        Função que salva uma transição na memória
        
        Parâmetros:
        -----------
        *args: {collections.namedtuple}
            transições que devem ser armazenadas na memória.
        ''' 
        if len(self.memory) < self.capacity: #Checa se a memória está cheia e, se não estiver,
            self.memory.append(None)         # cria um espaço vazio em que a transição será colocada
        
        self.memory[self.position] = Transition(*args) #armazena na memória usando o ponteiro self.position
        self.position = (self.position + 1) % self.capacity #atualiza o ponteiro

    def sample(self, batch_size):
        '''
        Função que amostra a memória, pegando batch_size's transições aleatoriamente.
        
        Parâmetros:
        -----------
        batch_size: {int}
            Número de transições que serão coletadas na amostra.
        
        Outputs:
        --------
        random.sample(self.memory, batch_size): {list}
            lista com batch_size's transições, escolhidas aleatoriamente.
        '''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''
        Função que coleta o número de transições guardadas na memória.
        
        Outputs:
        --------
        len(self.memory): {int}
            Número de transições armazenadas.
        '''
        return len(self.memory)

# %% [markdown]
# Após a implementação da memória, podemos implementar as redes neurais do agente e do crítico. Elas serão duas DNNs simples, constituídas por duas camadas lineares e uma camada de saída. Esperamos que você ja tenha familiaridade com esse tipo de implementação.

# %%
class Actor(nn.Module):
    def __init__(self, input_size, outputs):
        '''
        Classe que define a rede neural do agente do algoritmo.
        
        Parâmetros:
        -----------
        input_size: {int}
            tamanho da camada de entrada da rede;
        outputs: {int}
            tamanho da camada de saída da rede
        '''
        super(Actor, self).__init__()
        
        #Define a primeira camada linear com normalização
        self.linear1 = nn.Linear(input_size, 32)
        self.ln1 = nn.LayerNorm(32)

        #Define a segunda camada linear com normalização
        self.linear2 = nn.Linear(32, 64)
        self.ln2 = nn.LayerNorm(64)

        #Define a camada de saída
        self.linear3 = nn.Linear(64, outputs)
        
        self.tanh = nn.Tanh() #Definição da função de ativação tangente hiperbólica.

    def forward(self, state):
        '''
        Função que recebe o estado e decide a ação seguindo a sua política.
        
        Parâmetros:
        -----------
        state: {torch.tensor}
            tensor que representa o estado do ambiente.
        
        Outputs:
        --------
        action: {torch.tensor}
            tensor com a ação decidida.
        '''
        out = nn.functional.relu(self.ln1(self.linear1(state))) #Execução da primeira camada
        out = nn.functional.relu(self.ln2(self.linear2(out))) #Execução da segunda camada
        action = self.tanh(self.linear3(out)) #Execução da camada de saída
        
        return action

# %%
class Critic(nn.Module):
    def __init__(self, state_size, action_size, outputs):
        '''
        Classe que define a rede neural do crítico do algoritmo.
        
        Parâmetros:
        -----------
        state_size: {int}
            tamanho do estado do ambiente;
        action_size: {int}
            tamanho da ação do ambiente;    
        outputs: {int}
            tamanho da camada de saída da rede
        '''
        super(Critic, self).__init__()
        
        #Define a primeira camada linear com normalização
        self.linear1 = nn.Linear(state_size, 32)
        self.ln1 = nn.LayerNorm(32)

        #Define a segunda camada linear com normalização
        self.linear2 = nn.Linear(32 + action_size, 64) #A ação é adicionada apenas nessa segunda camada
        self.ln2 = nn.LayerNorm(64)

        #Define a camada de saída
        self.linear3 = nn.Linear(64, outputs)

    def forward(self, state, action):
        '''
        Função que recebe o estado e a ação e retorna o valor do estado-ação, o Q(s,a).
        
        Parâmetros:
        -----------
        state: {torch.tensor}
            tensor que representa o estado do ambiente.
        action: {torch.tensor}
            tensor que representa a ação realizada.
        
        Outputs:
        --------
        Q: {torch.tensor}
            tensor o valor do estado-ação, o Q(s,a).
        '''
        s1 = nn.functional.relu(self.ln1(self.linear1(state))) #Execução da primeira camada apenas com o estado
        out = torch.cat((s1,action), dim=1) #Concatenação da saída da primeira camada com a ação realizada
        out = nn.functional.relu(self.ln2(self.linear2(out))) #Execução da segunda camada
        Q = self.linear3(out) #Execução da camada de saída
        
        return Q

# %% [markdown]
# Finalizada a implementação da memória e das redes neurais, precisamos definir as configurações do nosso algoritmo. Primeiro, faremos uma investigação no nosso ambiente, analisando qual é o tamanho o estado, das ações esperadas e em qual intervalo a ação deve estar contida. Nas linhas de código abaixo guardamos essas informações.

# %%
input_size = int(env.observation_space.shape[0]) #shape do estado
output_size = int(env.action_space.shape[0]) #shape da ação
max_action = float(env.action_space.high[0]) #range válido para a ação
input_size, output_size, max_action
# Out:
# (3, 1, 2.0)

# %% [markdown]
# Além da configuração do ambiente, também precisamos configurar o nosso algoritmo. Na células abaixo, nós definiremos diversos parâmetros importantes para o treinamento. Começamos com os mais tradicionais.

# %%
BATCH_SIZE = 64 #Tamanho do batch
GAMMA = 0.95 #Taxa de aprendizado
tau = 0.05 #Parâmetro de suavização da sincronização

# %% [markdown]
# Agora, precisamos configurar nossos mecanismo de exploração. Nesse caso, nós disponibilizamos uma implementação do ruído nos parâmetros e uma do ruído na ação. Dessa forma, será possível comparar ambas as estratégias. As configurações estão disponíveis abaixo.

# %%
# Configuração do ruído no parâmetro
sigma = 0.3 #Desvio padrão do ruído gaussiano que será inserido nos parâmetros
alfa = 1.1 #Parâmetro de adaptação do ruído nos parâmetros
delta = 2e-1 #Limiar de decisão de correção do ruído nos parâmetros
T_adapt = 5 #Número de episódios entre as atualizações do ruído nos parâmetros

# Configuração do ruído na ação
desv_pad_ac = 0.3 #Desvio padrão do ruído gaussiano que será inserido na ação
alfa_ac = 1.08 #Parâmetro de adaptação do ruído na ação
T_adapt_ac = 5 #Número de episódios entre as atualizações do ruído na ação

# %% [markdown]
# Por fim, devemos instanciar as nossas redes neurais, sincronizá-las e configurar os otimizadores e funções de perda para aprendizado das redes. Tudo isso está sendo feito na célula abaixo, além do instanciamento da memória, com capacidade de armazenamento de 10 mil transições.

# %%
# Definição das redes do agente, incluindo a target e a utilizada para implementação do ruído nos parâmetros
actor_net = Actor(input_size, output_size).to(device)
actor_noise_net = Actor(input_size, output_size).to(device)
actor_target_net = Actor(input_size, output_size).to(device)

# Definição das redes do crítico, incluindo a target
critic_net = Critic(input_size, output_size, 1).to(device)
critic_target_net = Critic(input_size, output_size, 1).to(device)

# Sincronização das redes
actor_target_net.load_state_dict(actor_net.state_dict())
actor_target_net.eval()
actor_noise_net.load_state_dict(actor_net.state_dict())
actor_noise_net.eval()
critic_target_net.load_state_dict(critic_net.state_dict())
critic_target_net.eval()

# Definição dos otimizadores
optimizer_critic = torch.optim.Adam(critic_net.parameters(), lr=0.001)
optimizer_actor = torch.optim.Adam(actor_net.parameters(), lr=0.0001)

# Instanciamento da memória
memory = ReplayMemory(10000)

# Definição das funções de perda
loss_critic = nn.MSELoss() #Função de perda para otimização do crítico
loss_d = nn.MSELoss() #Função para ajuste dos parâmetros para utilização do ruído nos parâmetros para exploração

# Inicialização das variáveis de perda
actor_loss = None
critic_loss = None

# %% [markdown]
# A partir de todas essas configurações, podemos definir a função responsável por selecionar a ação que deve ser executada, levando em conta tanto a política, como a estratégia de exploração adotada. Essa função está implementada abaixo.

# %%
def select_action(state, action_noise=None, param_noise=None):
    '''
    Função que recebe o estado e decide a ação, levando em conta a política e o mecanismo de exploração.
        
    Parâmetros:
    -----------
    state: {torch.tensor}
        tensor que representa o estado do ambiente.
    action_noise: {boolean}
        flag que define se utilizaremos os ruídos na ação.
    param_noise: {boolean}
        flag que define se utilizaremos os ruídos nos parâmetros.
       
    Outputs:
    --------
    mu: {torch.tensor}
        tensor com a ação escolhida pela política.
    '''
    #Definição das redes em estado de avaliação e não de treino
    actor_net.eval()
    actor_noise_net.eval()
    
    if param_noise is not None:  #Se usar o ruído nos parâmetros,
        mu = actor_noise_net(state.float()) # utilize a rede ruidosa
    else: #Se não usar
        mu = actor_net(state.float()) # utilize a rede sem ruído
    
    mu = mu.data #Correção no formato do tensor
    
    if action_noise is not None: #Se usar o ruído na ação,
        with torch.no_grad(): 
            # soma o ruído na saída da rede
            mu = torch.Tensor(mu.cpu().numpy() + np.random.normal(0,desv_pad_ac,output_size)).to(device) 
    
    mu = mu.squeeze() #corrige o formato do tensor
    mu = max_action*mu.clamp(min=-1,max=1) #multiplica a ação no range válido
    
    return mu

# %% [markdown]
# Também definimos uma função responsável por fazer a sincronização suavizada entre os parâmetros de duas redes neurais.

# %%
def weightSync(target_model, source_model):
    '''
    Função que executa a sincronização das redes de maneira suavizada
    
    Parâmetros:
    -----------
    target_model: {torch.nn}
        rede neural que receberá os parâmetros da rede source_model de maneira suavizada.
    source_model: {torch.nn}
        rede neural que fornecerá os parâmetros para a outra rede.
    '''
    #Copia os parâmetros, suavizando a sincronização
    for parameter_target, parameter_source in zip(target_model.parameters(), source_model.parameters()):
        parameter_target.data.copy_((1 - tau) * parameter_target.data + tau * parameter_source.data)

# %% [markdown]
# Por fim, devemos implementar a função de otimização das redes neurais, onde a equação de Bellman será implementada e as redes serão atualizadas.

# %%
def optimize_model():
    '''
    Função utilizada para aprendizado das redes neurais
        
    Outputs:
    --------
    state_batch: {torch.tensor}
        batch com os tensores que representam os estados.
    action_batch: {torch.tensor}
        batch com os tensores que representam as ações.
    OBS: essas saídas servem para, posteriormente, ajustar a configuração do ruído nos parâmetros
    '''
    if len(memory) < BATCH_SIZE: #Verifica se a memória ja tem BATCH_SIZE's amostras
        return
    
    #Define que as redes estão em treinamento
    actor_net.train()
    critic_net.train()
    actor_noise_net.train()
    
    #Amostra a memória em BATCH_SIZE's transições
    transitions = memory.sample(BATCH_SIZE)
    batch = Transition(*zip(*transitions))

    #Define os tensores que serão utilizados no treinamento, 
    # agrupando os estados, ações e recompensas de todas as transições
    next_state_batch = torch.autograd.Variable(torch.cat(batch.next_state)).to(device)
    state_batch = torch.cat(batch.state).to(device)
    action_batch = []
    for tupla in batch.action:
        action_batch.append(np.array(tupla.cpu()))
    action_batch = torch.from_numpy(np.array(action_batch)).view(-1,1).to(device)
    reward_batch = torch.cat(batch.reward)
    
    #Calcula as ações a partir da rede target recebendo os estados vivenciados
    next_actor_action_value = actor_target_net(next_state_batch.float())
    #Calcula os Q(s,a) a partir dos estados e das ações calculadas pela rede agente do target
    with torch.no_grad():
        next_state_values = critic_target_net(next_state_batch.float(), next_actor_action_value.float()).squeeze()

    #Calcula o lado direito da equação de Bellman
    expected_state_action_values = (next_state_values * GAMMA) + reward_batch

    ### Otimização do crítico ###
    optimizer_critic.zero_grad()
    #Cálculo do Q usando a rede que NÃO é target e as ações decididas originalmente
    state_action_values = critic_net(state_batch.float(), action_batch.float())
    #Calcula a diferença entre os dois lados da equação de Bellman
    critic_loss = loss_critic(state_action_values.float().squeeze(), expected_state_action_values.float())
    #Otimiza os parâmetros da rede
    critic_loss.backward()
    optimizer_critic.step()
    ###  ###
    
    ### Otimização do agente ###
    optimizer_actor.zero_grad()
    #Cálculo do -Q usando a rede que NÃO é target e as decisões do agente que NÃO é target
    gradient = -critic_net(state_batch.float(), actor_net(state_batch.float()).float()) 
    #Calculo da função de perda como a média dos -Q estimados na linha acima
    actor_loss = torch.mean(gradient)
    #Otimiza os parâmetros da rede
    actor_loss.backward()
    optimizer_actor.step()
    ###  ###
    
    #Sincronização suavizada entre redes originais e redes target
    weightSync(actor_target_net, actor_net)
    weightSync(critic_target_net, critic_net)
    
    return state_batch, action_batch

# %% [markdown]
# Com todos os elementos configurados e todas as funções necessárias definidas, podemos realizar o processo de treinamento. Ele será feito em 500 episódios e, inicialmente, utilizaremos o ruído nos parâmetros para exploração. O retorno por episódio será armazenado para ser plotado, posteriormente.

# %%
'''
Rotina de treinamento do algoritmo
'''
num_episodes = 500
list_retorno = []
param_noise, ac_noise = True, None
for i_episode in range(num_episodes):
    #Inicializa o ambiente e coleta o estado inicial
    state = env.reset()
    
    #Inicializa as variáveis de retorno e número de eventos
    retorno, steps = 0,0
    
    #Loop que adiciona o ruído nos parâmetros da rede actor_noise_net()
    for parameter_ruido, parameter_original in zip(actor_noise_net.parameters(), actor_net.parameters()):
        parameter_ruido.data.copy_(parameter_original.data + sigma*torch.randn(parameter_original.data.shape).to(device))

    #Inicializa a contagem de eventos no episódio
    for t in count():
        env.render() #Renderiza o ambiente
        
        action = select_action(torch.FloatTensor([state]).to(device), ac_noise, param_noise).cpu() #Seleciona a ação 
                                                                                                   # a partir do estado
        next_state, reward, done, _ = env.step([action]) #Executa a ação e coleta o prox estado, 
                                                         # a recompensa e se o episódio foi finalizado
        reward = reward/10 #Ajusta o valor da recompensa
        
        #Soma a recompensa ao retorno
        retorno += reward

        #Guarda a experiência na memória
        memory.push(torch.FloatTensor([state]),
                     action.to(device),
                     torch.FloatTensor([next_state]),
                     torch.FloatTensor([reward]).to(device))

        #Move para o proximo estado e atualiza o ponteiro de eventos
        state = next_state
        steps += 1
        
        #Otimiza a rede neural do crítico
        if optimize_model() != None:
            state_batch, action_batch = optimize_model()
        if done:
            break
    
    # Se estiver usando o ruído na ação
    if ac_noise == True:
        if (i_episode+1) % T_adapt_ac == 0: #Checa se está no período de adaptação
            desv_pad_ac = desv_pad_ac/alfa_ac #Adapta o desvio padrão do ruído que será inserido na ação
            print('\n Sigma: ', desv_pad_ac)
            
    # Se estiver usando o ruído nos parâmetros
    if param_noise == True:
        if (i_episode+1) % T_adapt == 0: #Checa se está no período de adaptação
            unpertubed_action = select_action(state_batch) #Decide as ações sem nenhum ruído
            perturbed_actions = action_batch #Guarda as ações geradas pelas redes ruidosas
            
            d = loss_d(unpertubed_action, perturbed_actions) #Calcula a diferença quadrática 
                                                             # entre as ações ruidosas e não ruidosas
            d = torch.mean(d) #Calcula a média no batch
            
            if d <= delta: #Se a distância for MENOR do que o limiar de decisão
                sigma = sigma*alfa #Aumenta o desvio padrão do ruído
            else: #Se a distância for MAIOR do que o limiar de decisão
                sigma = sigma/alfa #Diminui o desvio padrão do ruído
            
            print(" \nD: ", d.item(), '   Sigma: ', sigma)
    
    #Printa o retorno do episódio e guarda em uma lista
    print(f'Episodio {i_episode}: retorno={round(retorno,2)}')
    list_retorno.append(retorno)

print('Complete')
env.render()
env.close()
# Out:
# Episodio 0: retorno=-160.29 || média acao=-1.77
# Episodio 1: retorno=-166.05 || média acao=-0.91
# Episodio 2: retorno=-157.92 || média acao=1.15
# Episodio 3: retorno=-164.67 || média acao=1.97
# C:\Users\gabri\Anaconda3\lib\site-packages\torch\nn\modules\loss.py:446: UserWarning: Using a target size (torch.Size([64, 1])) that is different to the input size (torch.Size([64])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
#
# D:  7.25479793548584    Sigma:  0.2727272727272727
# Episodio 4: retorno=-140.65 || média acao=-1.03
# Episodio 5: retorno=-146.1 || média acao=-1.18
# Episodio 6: retorno=-162.96 || média acao=-1.95
# Episodio 7: retorno=-145.83 || média acao=1.31
# Episodio 8: retorno=-138.31 || média acao=-1.18
#
# D:  6.530818939208984    Sigma:  0.2479338842975206
# Episodio 9: retorno=-153.08 || média acao=1.4
# Episodio 10: retorno=-153.21 || média acao=1.34
# Episodio 11: retorno=-163.08 || média acao=1.12
# Episodio 12: retorno=-131.2 || média acao=-1.88
# Episodio 13: retorno=-144.16 || média acao=1.31
#
# D:  6.310327053070068    Sigma:  0.22539444027047326
# Episodio 14: retorno=-149.38 || média acao=1.66
# Episodio 15: retorno=-138.34 || média acao=1.93
# Episodio 16: retorno=-133.94 || média acao=0.41
# Episodio 17: retorno=-148.89 || média acao=1.06
# Episodio 18: retorno=-122.64 || média acao=1.86
#
# D:  6.744060039520264    Sigma:  0.2049040366095211
# Episodio 19: retorno=-135.05 || média acao=-0.86
# Episodio 20: retorno=-109.72 || média acao=-1.8
# Episodio 21: retorno=-159.42 || média acao=1.74
# Episodio 22: retorno=-150.02 || média acao=2.0
# Episodio 23: retorno=-149.01 || média acao=-1.81
#
# D:  6.62432336807251    Sigma:  0.18627639691774645
# Episodio 24: retorno=-128.63 || média acao=0.32
# Episodio 25: retorno=-96.15 || média acao=1.26
# Episodio 26: retorno=-143.68 || média acao=-1.65
# Episodio 27: retorno=-138.07 || média acao=-1.32
# Episodio 28: retorno=-152.09 || média acao=1.68
#
# D:  6.344508171081543    Sigma:  0.16934217901613313
# Episodio 29: retorno=-140.0 || média acao=-0.94
# Episodio 30: retorno=-152.5 || média acao=0.88
# Episodio 31: retorno=-146.68 || média acao=0.53
# Episodio 32: retorno=-122.66 || média acao=1.57
# Episodio 33: retorno=-141.84 || média acao=-1.78
#
# D:  6.359169006347656    Sigma:  0.1539474354692119
# Episodio 34: retorno=-134.37 || média acao=-1.5
# Episodio 35: retorno=-111.56 || média acao=1.33
# Episodio 36: retorno=-145.11 || média acao=-1.2
# Episodio 37: retorno=-90.41 || média acao=-0.48
# Episodio 38: retorno=-139.08 || média acao=1.05
#
# D:  6.7019453048706055    Sigma:  0.1399522140629199
# Episodio 39: retorno=-139.49 || média acao=-1.45
# Episodio 40: retorno=-136.8 || média acao=0.25
# Episodio 41: retorno=-134.81 || média acao=0.53
# Episodio 42: retorno=-116.39 || média acao=0.47
# Episodio 43: retorno=-152.77 || média acao=-1.64
#
# D:  6.4528608322143555    Sigma:  0.12722928551174537
# Episodio 44: retorno=-147.07 || média acao=0.13
# Episodio 45: retorno=-150.62 || média acao=-1.66
# Episodio 46: retorno=-152.69 || média acao=-1.45
# Episodio 47: retorno=-0.12 || média acao=-0.36
# Episodio 48: retorno=-120.66 || média acao=-1.35
#
# D:  6.258975505828857    Sigma:  0.11566298682885942
# Episodio 49: retorno=-134.71 || média acao=1.2
# Episodio 50: retorno=-48.9 || média acao=1.0
# Episodio 51: retorno=-134.6 || média acao=-0.86
# Episodio 52: retorno=-132.86 || média acao=0.47
# Episodio 53: retorno=-140.49 || média acao=-1.41
#
# D:  6.633335113525391    Sigma:  0.10514816984441765
# Episodio 54: retorno=-102.31 || média acao=0.05
# Episodio 55: retorno=-155.21 || média acao=-1.69
# Episodio 56: retorno=-127.5 || média acao=-0.39
# Episodio 57: retorno=-142.23 || média acao=0.72
# Episodio 58: retorno=-141.79 || média acao=1.02
#
# D:  6.187716960906982    Sigma:  0.09558924531310695
# Episodio 59: retorno=-77.79 || média acao=-0.71
# Episodio 60: retorno=-25.34 || média acao=0.51
# Episodio 61: retorno=-155.11 || média acao=1.39
# Episodio 62: retorno=-128.97 || média acao=0.31
# Episodio 63: retorno=-150.66 || média acao=1.8
#
# D:  6.169685363769531    Sigma:  0.0868993139210063
# Episodio 64: retorno=-14.23 || média acao=1.06
# Episodio 65: retorno=-108.3 || média acao=1.57
# Episodio 66: retorno=-118.98 || média acao=-0.38
# Episodio 67: retorno=-39.74 || média acao=0.6
# Episodio 68: retorno=-160.57 || média acao=1.57
#
# D:  5.941171646118164    Sigma:  0.07899937629182391
# Episodio 69: retorno=-150.3 || média acao=1.71
# Episodio 70: retorno=-126.82 || média acao=-0.34
# Episodio 71: retorno=-102.33 || média acao=-0.29
# Episodio 72: retorno=-88.96 || média acao=0.42
# Episodio 73: retorno=-47.07 || média acao=0.73
#
# D:  5.718972682952881    Sigma:  0.071817614810749
# Episodio 74: retorno=-118.83 || média acao=0.9
# Episodio 75: retorno=-115.32 || média acao=0.93
# Episodio 76: retorno=-0.2 || média acao=0.08
# Episodio 77: retorno=-146.33 || média acao=1.36
# Episodio 78: retorno=-115.73 || média acao=1.42
#
# D:  6.458565711975098    Sigma:  0.06528874073704453
# Episodio 79: retorno=-42.56 || média acao=-0.95
# Episodio 80: retorno=-107.92 || média acao=1.35
# Episodio 81: retorno=-12.74 || média acao=0.04
# Episodio 82: retorno=-148.57 || média acao=1.19
# Episodio 83: retorno=-0.1 || média acao=-0.24
#
# D:  6.091421127319336    Sigma:  0.05935340067004048
# Episodio 84: retorno=-161.66 || média acao=2.0
# Episodio 85: retorno=-127.72 || média acao=0.82
# Episodio 86: retorno=-156.61 || média acao=1.72
# Episodio 87: retorno=-12.38 || média acao=-0.07
# Episodio 88: retorno=-133.76 || média acao=-0.23
#
# D:  6.126402378082275    Sigma:  0.05395763697276407
# Episodio 89: retorno=-99.16 || média acao=0.92
# Episodio 90: retorno=-62.86 || média acao=-0.18
# Episodio 91: retorno=-0.01 || média acao=-0.07
# Episodio 92: retorno=-148.45 || média acao=1.39
# Episodio 93: retorno=-136.39 || média acao=1.03
#
# D:  6.429553031921387    Sigma:  0.04905239724796733
# Episodio 94: retorno=-24.91 || média acao=-0.11
# Episodio 95: retorno=-0.06 || média acao=-0.17
# Episodio 96: retorno=-146.45 || média acao=1.24
# Episodio 97: retorno=-79.76 || média acao=-0.04
# Episodio 98: retorno=-24.55 || média acao=-0.12
#
# D:  6.0681047439575195    Sigma:  0.04459308840724303
# Episodio 99: retorno=-98.42 || média acao=-0.19
# Episodio 100: retorno=-12.95 || média acao=-0.42
# Episodio 101: retorno=-98.24 || média acao=0.35
# Episodio 102: retorno=-1.18 || média acao=1.19
# Episodio 103: retorno=-134.71 || média acao=0.67
#
# D:  6.018726825714111    Sigma:  0.040539171279311836
# Episodio 104: retorno=-112.27 || média acao=-0.33
# Episodio 105: retorno=-0.18 || média acao=0.43
# Episodio 106: retorno=-13.14 || média acao=0.94
# Episodio 107: retorno=-11.44 || média acao=0.08
# Episodio 108: retorno=-12.11 || média acao=-0.1
#
# D:  5.879361629486084    Sigma:  0.03685379207210167
# Episodio 109: retorno=-159.15 || média acao=1.52
# Episodio 110: retorno=-98.71 || média acao=-0.07
# Episodio 111: retorno=-23.33 || média acao=0.01
# Episodio 112: retorno=-12.64 || média acao=0.7
# Episodio 113: retorno=-24.66 || média acao=-0.83
#
# D:  5.67413330078125    Sigma:  0.03350344733827424
# Episodio 114: retorno=-0.11 || média acao=-0.31
# Episodio 115: retorno=-12.63 || média acao=-0.13
# Episodio 116: retorno=-25.38 || média acao=0.71
# Episodio 117: retorno=-36.16 || média acao=-0.02
# Episodio 118: retorno=-12.42 || média acao=0.02
#
# D:  6.184061050415039    Sigma:  0.030457679398431126
# Episodio 119: retorno=-0.49 || média acao=0.66
# Episodio 120: retorno=-22.68 || média acao=0.24
# Episodio 121: retorno=-0.35 || média acao=-0.11
# Episodio 122: retorno=-50.36 || média acao=-1.03
# Episodio 123: retorno=-23.65 || média acao=-0.06
#
# D:  6.305682182312012    Sigma:  0.027688799453119202
# Episodio 124: retorno=-90.34 || média acao=-0.39
# Episodio 125: retorno=-12.75 || média acao=-0.51
# Episodio 126: retorno=-12.65 || média acao=-0.25
# Episodio 127: retorno=-26.22 || média acao=-0.01
# Episodio 128: retorno=-30.78 || média acao=0.49
#
# D:  5.579993724822998    Sigma:  0.025171635866472
# Episodio 129: retorno=-0.12 || média acao=-0.15
# Episodio 130: retorno=-12.13 || média acao=0.48
# Episodio 131: retorno=-25.56 || média acao=0.16
# Episodio 132: retorno=-25.4 || média acao=0.47
# Episodio 133: retorno=-12.72 || média acao=-0.31
#
# D:  6.1291584968566895    Sigma:  0.02288330533315636
# Episodio 134: retorno=-27.51 || média acao=0.16
# Episodio 135: retorno=-12.68 || média acao=0.1
# Episodio 136: retorno=-12.59 || média acao=0.01
# Episodio 137: retorno=-22.79 || média acao=0.02
# Episodio 138: retorno=-12.03 || média acao=0.37
#
# D:  5.669227600097656    Sigma:  0.020803004848323963
# Episodio 139: retorno=-12.2 || média acao=0.27
# Episodio 140: retorno=-12.55 || média acao=0.86
# Episodio 141: retorno=-12.35 || média acao=0.04
# Episodio 142: retorno=-11.95 || média acao=0.18
# Episodio 143: retorno=-0.3 || média acao=0.42
#
# D:  5.860836029052734    Sigma:  0.01891182258938542
# Episodio 144: retorno=-12.2 || média acao=0.39
# Episodio 145: retorno=-12.39 || média acao=-0.0
# Episodio 146: retorno=-36.0 || média acao=-0.04
# Episodio 147: retorno=-11.84 || média acao=0.23
# Episodio 148: retorno=-24.58 || média acao=-0.09
#
# D:  5.117825508117676    Sigma:  0.01719256599035038
# Episodio 149: retorno=-24.01 || média acao=0.35
# Episodio 150: retorno=-12.54 || média acao=0.23
# Episodio 151: retorno=-32.56 || média acao=0.46
# Episodio 152: retorno=-27.63 || média acao=0.54
# Episodio 153: retorno=-12.87 || média acao=0.06
#
# D:  5.647209167480469    Sigma:  0.015629605445773073
# Episodio 154: retorno=-12.33 || média acao=-0.02
# Episodio 155: retorno=-12.35 || média acao=0.27
# Episodio 156: retorno=-11.89 || média acao=0.18
# Episodio 157: retorno=-11.98 || média acao=0.4
# Episodio 158: retorno=-13.03 || média acao=0.33
#
# D:  6.07772970199585    Sigma:  0.014208732223430064
# Episodio 159: retorno=-12.74 || média acao=0.47
# Episodio 160: retorno=-12.52 || média acao=0.22
# Episodio 161: retorno=-12.99 || média acao=-0.03
# Episodio 162: retorno=-37.74 || média acao=0.31
# Episodio 163: retorno=-22.96 || média acao=0.25
#
# D:  5.766417026519775    Sigma:  0.01291702929402733
# Episodio 164: retorno=-12.03 || média acao=0.23
# Episodio 165: retorno=-12.57 || média acao=0.17
# Episodio 166: retorno=-0.3 || média acao=0.55
# Episodio 167: retorno=-0.14 || média acao=0.14
# Episodio 168: retorno=-12.09 || média acao=0.24
#
# D:  6.01754903793335    Sigma:  0.011742753903661208
# Episodio 169: retorno=-11.6 || média acao=0.63
# Episodio 170: retorno=-22.88 || média acao=0.28
# Episodio 171: retorno=-12.12 || média acao=0.16
# Episodio 172: retorno=-12.48 || média acao=0.31
# Episodio 173: retorno=-12.39 || média acao=-0.19
#
# D:  6.129826068878174    Sigma:  0.010675230821510189
# Episodio 174: retorno=-12.44 || média acao=0.38
# Episodio 175: retorno=-13.11 || média acao=0.19
# Episodio 176: retorno=-24.91 || média acao=0.61
# Episodio 177: retorno=-12.73 || média acao=0.06
# Episodio 178: retorno=-28.46 || média acao=0.4
#
# D:  5.296545028686523    Sigma:  0.00970475529228199
# Episodio 179: retorno=-11.85 || média acao=0.32
# Episodio 180: retorno=-0.19 || média acao=0.43
# Episodio 181: retorno=-12.13 || média acao=0.22
# Episodio 182: retorno=-13.07 || média acao=0.73
# Episodio 183: retorno=-26.1 || média acao=0.25
#
# D:  4.944231986999512    Sigma:  0.008822504811165444
# Episodio 184: retorno=-29.61 || média acao=0.46
# Episodio 185: retorno=-0.45 || média acao=0.47
# Episodio 186: retorno=-25.9 || média acao=0.48
# Episodio 187: retorno=-12.18 || média acao=0.05
# Episodio 188: retorno=-23.78 || média acao=0.32
#
# D:  5.199151039123535    Sigma:  0.008020458919241313
# Episodio 189: retorno=-0.22 || média acao=0.45
# Episodio 190: retorno=-37.06 || média acao=0.2
# Episodio 191: retorno=-12.64 || média acao=0.31
# Episodio 192: retorno=-12.84 || média acao=0.49
# Episodio 193: retorno=-11.61 || média acao=0.6
#
# D:  4.890780925750732    Sigma:  0.0072913262902193745
# Episodio 194: retorno=-12.13 || média acao=0.39
# Episodio 195: retorno=-0.16 || média acao=0.26
# Episodio 196: retorno=-12.41 || média acao=0.4
# Episodio 197: retorno=-12.87 || média acao=0.05
# Episodio 198: retorno=-11.95 || média acao=0.15
#
# D:  4.652563095092773    Sigma:  0.0066284784456539765
# Episodio 199: retorno=-24.15 || média acao=0.41
# Episodio 200: retorno=-12.58 || média acao=0.11
# Episodio 201: retorno=-12.31 || média acao=0.5
# Episodio 202: retorno=-36.3 || média acao=0.04
# Episodio 203: retorno=-12.79 || média acao=-0.13
#
# D:  4.581900119781494    Sigma:  0.006025889496049069
# Episodio 204: retorno=-23.19 || média acao=0.22
# Episodio 205: retorno=-35.58 || média acao=0.28
# Episodio 206: retorno=-23.58 || média acao=0.5
# Episodio 207: retorno=-0.39 || média acao=0.29
# Episodio 208: retorno=-35.74 || média acao=0.03
#
# D:  4.893437385559082    Sigma:  0.005478081360044608
# Episodio 209: retorno=-12.44 || média acao=0.41
# Episodio 210: retorno=-12.34 || média acao=0.41
# Episodio 211: retorno=-0.31 || média acao=0.55
# Episodio 212: retorno=-12.42 || média acao=0.29
# Episodio 213: retorno=-27.21 || média acao=0.33
#
# D:  4.610033988952637    Sigma:  0.004980073963676916
# Episodio 214: retorno=-34.4 || média acao=0.14
# Episodio 215: retorno=-0.26 || média acao=0.54
# Episodio 216: retorno=-25.32 || média acao=0.18
# Episodio 217: retorno=-12.69 || média acao=-0.3
# Episodio 218: retorno=-12.34 || média acao=0.09
#
# D:  5.1864190101623535    Sigma:  0.004527339966979014
# Episodio 219: retorno=-11.9 || média acao=-0.03
# Episodio 220: retorno=-35.06 || média acao=0.05
# Episodio 221: retorno=-26.24 || média acao=-0.44
# Episodio 222: retorno=-12.93 || média acao=-0.02
# Episodio 223: retorno=-24.25 || média acao=0.32
#
# D:  4.81015682220459    Sigma:  0.0041157636063445585
# Episodio 224: retorno=-26.69 || média acao=0.34
# Episodio 225: retorno=-12.21 || média acao=0.65
# Episodio 226: retorno=-0.21 || média acao=0.43
# Episodio 227: retorno=-0.25 || média acao=0.41
# Episodio 228: retorno=-11.42 || média acao=0.04
#
# D:  4.378655433654785    Sigma:  0.003741603278495053
# Episodio 229: retorno=-12.25 || média acao=0.29
# Episodio 230: retorno=-12.47 || média acao=0.29
# Episodio 231: retorno=-12.18 || média acao=0.34
# Episodio 232: retorno=-12.19 || média acao=0.14
# Episodio 233: retorno=-11.76 || média acao=0.29
#
# D:  4.553471565246582    Sigma:  0.0034014575259045934
# Episodio 234: retorno=-12.36 || média acao=0.33
# Episodio 235: retorno=-33.7 || média acao=0.28
# Episodio 236: retorno=-12.89 || média acao=0.2
# Episodio 237: retorno=-26.35 || média acao=0.13
# Episodio 238: retorno=-12.56 || média acao=0.11
#
# D:  4.593344688415527    Sigma:  0.003092234114458721
# Episodio 239: retorno=-11.33 || média acao=0.24
# Episodio 240: retorno=-0.09 || média acao=-0.02
# Episodio 241: retorno=-31.3 || média acao=0.26
# Episodio 242: retorno=-0.09 || média acao=0.0
# Episodio 243: retorno=-24.21 || média acao=0.02
#
# D:  3.8177998065948486    Sigma:  0.0028111219222352007
# Episodio 244: retorno=-12.33 || média acao=0.12
# Episodio 245: retorno=-0.24 || média acao=0.19
# Episodio 246: retorno=-32.64 || média acao=0.0
# Episodio 247: retorno=-12.35 || média acao=-0.05
# Episodio 248: retorno=-11.53 || média acao=-0.3
#
# D:  4.277468681335449    Sigma:  0.002555565383850182
# Episodio 249: retorno=-23.92 || média acao=-0.1
# Episodio 250: retorno=-11.46 || média acao=0.0
# Episodio 251: retorno=-11.57 || média acao=0.11
# Episodio 252: retorno=-12.58 || média acao=0.14
# Episodio 253: retorno=-23.49 || média acao=-0.06
#
# D:  4.825582504272461    Sigma:  0.00232324125804562
# Episodio 254: retorno=-0.11 || média acao=0.05
# Episodio 255: retorno=-25.91 || média acao=-0.11
# Episodio 256: retorno=-0.28 || média acao=0.12
# Episodio 257: retorno=-29.22 || média acao=0.14
# Episodio 258: retorno=-12.71 || média acao=0.21
#
# D:  4.9174113273620605    Sigma:  0.0021120375073141995
# Episodio 259: retorno=-36.5 || média acao=0.17
# Episodio 260: retorno=-12.23 || média acao=0.18
# Episodio 261: retorno=-26.19 || média acao=0.36
# Episodio 262: retorno=-11.67 || média acao=-0.1
# Episodio 263: retorno=-0.13 || média acao=-0.14
#
# D:  5.259066581726074    Sigma:  0.001920034097558363
# Episodio 264: retorno=-12.68 || média acao=0.25
# Episodio 265: retorno=-0.17 || média acao=0.09
# Episodio 266: retorno=-12.69 || média acao=-0.02
# Episodio 267: retorno=-0.21 || média acao=0.38
# Episodio 268: retorno=-12.23 || média acao=0.28
#
# D:  5.341578483581543    Sigma:  0.0017454855432348752
# Episodio 269: retorno=-12.61 || média acao=0.19
# Episodio 270: retorno=-26.79 || média acao=0.13
# Episodio 271: retorno=-13.15 || média acao=0.2
# Episodio 272: retorno=-13.08 || média acao=0.5
# Episodio 273: retorno=-23.57 || média acao=0.09
#
# D:  5.199305534362793    Sigma:  0.0015868050393044318
# Episodio 274: retorno=-36.16 || média acao=0.13
# Episodio 275: retorno=-12.38 || média acao=0.38
# Episodio 276: retorno=-28.49 || média acao=0.2
# Episodio 277: retorno=-13.46 || média acao=-0.0
# Episodio 278: retorno=-12.26 || média acao=-0.01
#
# D:  5.445279598236084    Sigma:  0.0014425500357313015
# Episodio 279: retorno=-13.34 || média acao=0.18
# Episodio 280: retorno=-11.68 || média acao=0.48
# Episodio 281: retorno=-13.12 || média acao=0.03
# Episodio 282: retorno=-12.52 || média acao=0.25
# Episodio 283: retorno=-24.06 || média acao=0.42
#
# D:  6.208195686340332    Sigma:  0.0013114091233920923
# Episodio 284: retorno=-12.89 || média acao=0.28
# Episodio 285: retorno=-24.15 || média acao=0.33
# Episodio 286: retorno=-23.83 || média acao=0.37
# Episodio 287: retorno=-23.7 || média acao=-0.06
# Episodio 288: retorno=-11.87 || média acao=0.37
#
# D:  5.238664627075195    Sigma:  0.0011921901121746293
# Episodio 289: retorno=-0.18 || média acao=0.33
# Episodio 290: retorno=-12.93 || média acao=-0.1
# Episodio 291: retorno=-0.13 || média acao=-0.16
# Episodio 292: retorno=-12.69 || média acao=-0.26
# Episodio 293: retorno=-34.43 || média acao=0.07
#
# D:  5.779669761657715    Sigma:  0.0010838091928860266
# Episodio 294: retorno=-12.72 || média acao=0.32
# Episodio 295: retorno=-11.54 || média acao=-0.14
# Episodio 296: retorno=-26.96 || média acao=-0.03
# Episodio 297: retorno=-12.93 || média acao=-0.05
# Episodio 298: retorno=-13.0 || média acao=0.04
#
# D:  5.944883346557617    Sigma:  0.0009852810844418424
# Episodio 299: retorno=-12.25 || média acao=0.2
# Episodio 300: retorno=-12.57 || média acao=0.27
# Episodio 301: retorno=-12.43 || média acao=0.02
# Episodio 302: retorno=-0.17 || média acao=-0.25
# Episodio 303: retorno=-13.22 || média acao=-0.17
#
# D:  6.2538299560546875    Sigma:  0.0008957100767653112
# Episodio 304: retorno=-12.71 || média acao=-0.11
# Episodio 305: retorno=-0.44 || média acao=-0.61
# Episodio 306: retorno=-24.55 || média acao=-0.49
# Episodio 307: retorno=-27.47 || média acao=-0.61
# Episodio 308: retorno=-25.41 || média acao=-0.52
#
# D:  5.598624229431152    Sigma:  0.0008142818879684646
# Episodio 309: retorno=-35.33 || média acao=-0.47
# Episodio 310: retorno=-25.88 || média acao=-0.31
# Episodio 311: retorno=-12.46 || média acao=-0.49
# Episodio 312: retorno=-0.21 || média acao=-0.34
# Episodio 313: retorno=-12.81 || média acao=0.49
#
# D:  5.520962715148926    Sigma:  0.0007402562617895133
# Episodio 314: retorno=-0.12 || média acao=-0.12
# Episodio 315: retorno=-25.98 || média acao=-0.05
# Episodio 316: retorno=-13.35 || média acao=-0.14
# Episodio 317: retorno=-12.47 || média acao=0.16
# Episodio 318: retorno=-12.07 || média acao=0.11
#
# D:  6.713388442993164    Sigma:  0.0006729602379904665
# Episodio 319: retorno=-13.29 || média acao=0.01
# Episodio 320: retorno=-25.02 || média acao=-0.12
# Episodio 321: retorno=-12.83 || média acao=-0.0
# Episodio 322: retorno=-26.22 || média acao=-0.03
# Episodio 323: retorno=-12.88 || média acao=-0.07
#
# D:  6.6151885986328125    Sigma:  0.0006117820345367877
# Episodio 324: retorno=-26.03 || média acao=0.21
# Episodio 325: retorno=-12.38 || média acao=0.05
# Episodio 326: retorno=-26.21 || média acao=0.25
# Episodio 327: retorno=-24.41 || média acao=-0.06
# Episodio 328: retorno=-24.31 || média acao=0.48
#
# D:  5.598684310913086    Sigma:  0.0005561654859425342
# Episodio 329: retorno=-13.23 || média acao=0.66
# Episodio 330: retorno=-149.19 || média acao=-2.0
# Episodio 331: retorno=-0.22 || média acao=0.38
# Episodio 332: retorno=-12.25 || média acao=0.42
# Episodio 333: retorno=-0.18 || média acao=0.39
#
# D:  6.533243656158447    Sigma:  0.0005056049872204856
# Episodio 334: retorno=-11.67 || média acao=0.28
# Episodio 335: retorno=-0.37 || média acao=0.62
# Episodio 336: retorno=-0.65 || média acao=0.23
# Episodio 337: retorno=-12.5 || média acao=0.32
# Episodio 338: retorno=-11.71 || média acao=-0.15
#
# D:  5.489842414855957    Sigma:  0.0004596408974731687
# Episodio 339: retorno=-23.05 || média acao=0.27
# Episodio 340: retorno=-25.85 || média acao=1.03
# Episodio 341: retorno=-0.19 || média acao=0.2
# Episodio 342: retorno=-12.16 || média acao=0.15
# Episodio 343: retorno=-11.7 || média acao=0.46
#
# D:  6.110644340515137    Sigma:  0.00041785536133924424
# Episodio 344: retorno=-24.6 || média acao=-0.07
# Episodio 345: retorno=-12.85 || média acao=0.11
# Episodio 346: retorno=-12.21 || média acao=0.4
# Episodio 347: retorno=-12.16 || média acao=0.4
# Episodio 348: retorno=-23.25 || média acao=0.23
#
# D:  6.341794967651367    Sigma:  0.0003798685103084038
# Episodio 349: retorno=-22.72 || média acao=0.12
# Episodio 350: retorno=-12.81 || média acao=0.22
# Episodio 351: retorno=-13.15 || média acao=0.11
# Episodio 352: retorno=-13.09 || média acao=-0.09
# Episodio 353: retorno=-24.96 || média acao=0.22
#
# D:  7.045965194702148    Sigma:  0.00034533500937127616
# Episodio 354: retorno=-24.28 || média acao=-0.09
# Episodio 355: retorno=-13.14 || média acao=0.21
# Episodio 356: retorno=-11.82 || média acao=-0.07
# Episodio 357: retorno=-12.19 || média acao=0.36
# Episodio 358: retorno=-12.57 || média acao=0.25
#
# D:  6.205239295959473    Sigma:  0.00031394091761025104
# Episodio 359: retorno=-24.37 || média acao=0.42
# Episodio 360: retorno=-12.39 || média acao=0.19
# Episodio 361: retorno=-23.87 || média acao=0.06
# Episodio 362: retorno=-13.46 || média acao=0.04
# Episodio 363: retorno=-31.84 || média acao=0.13
#
# D:  6.297510147094727    Sigma:  0.0002854008341911373
# Episodio 364: retorno=-23.6 || média acao=-0.06
# Episodio 365: retorno=-23.99 || média acao=0.37
# Episodio 366: retorno=-24.15 || média acao=0.22
# Episodio 367: retorno=-12.91 || média acao=0.13
# Episodio 368: retorno=-22.77 || média acao=0.17
#
# D:  6.557967185974121    Sigma:  0.0002594553038101248
# Episodio 369: retorno=-36.61 || média acao=0.32
# Episodio 370: retorno=-12.81 || média acao=0.19
# Episodio 371: retorno=-25.0 || média acao=0.29
# Episodio 372: retorno=-24.84 || média acao=0.04
# Episodio 373: retorno=-12.33 || média acao=0.27
#
# D:  6.1863508224487305    Sigma:  0.00023586845800920435
# Episodio 374: retorno=-23.98 || média acao=-0.03
# Episodio 375: retorno=-25.72 || média acao=-0.1
# Episodio 376: retorno=-12.45 || média acao=-0.09
# Episodio 377: retorno=-12.76 || média acao=0.19
# Episodio 378: retorno=-26.8 || média acao=0.06
#
# D:  5.8815813064575195    Sigma:  0.00021442587091745848
# Episodio 379: retorno=-11.92 || média acao=0.38
# Episodio 380: retorno=-11.5 || média acao=0.24
# Episodio 381: retorno=-34.16 || média acao=-0.01
# Episodio 382: retorno=-12.53 || média acao=0.04
# Episodio 383: retorno=-12.94 || média acao=-0.03
#
# D:  6.702397346496582    Sigma:  0.00019493260992496224
# Episodio 384: retorno=-12.67 || média acao=0.05
# Episodio 385: retorno=-24.04 || média acao=-0.17
# Episodio 386: retorno=-12.7 || média acao=-0.2
# Episodio 387: retorno=-12.21 || média acao=-0.29
# Episodio 388: retorno=-26.35 || média acao=-0.04
#
# D:  6.627508163452148    Sigma:  0.00017721146356814747
# Episodio 389: retorno=-11.7 || média acao=0.24
# Episodio 390: retorno=-25.01 || média acao=-0.05
# Episodio 391: retorno=-27.86 || média acao=-0.01
# Episodio 392: retorno=-12.73 || média acao=-0.08
# Episodio 393: retorno=-12.96 || média acao=-0.13
#
# D:  7.127846717834473    Sigma:  0.0001611013305164977
# Episodio 394: retorno=-12.69 || média acao=-0.24
# Episodio 395: retorno=-26.35 || média acao=0.02
# Episodio 396: retorno=-0.17 || média acao=-0.08
# Episodio 397: retorno=-12.22 || média acao=-0.21
# Episodio 398: retorno=-12.6 || média acao=0.17
#
# D:  6.822107315063477    Sigma:  0.00014645575501499788
# Episodio 399: retorno=-23.73 || média acao=0.03
# Episodio 400: retorno=-12.92 || média acao=0.17
# Episodio 401: retorno=-13.01 || média acao=0.03
# Episodio 402: retorno=-12.74 || média acao=-0.1
# Episodio 403: retorno=-0.36 || média acao=0.11
#
# D:  7.188019752502441    Sigma:  0.00013314159546817987
# Episodio 404: retorno=-0.19 || média acao=0.18
# Episodio 405: retorno=-13.46 || média acao=0.39
# Episodio 406: retorno=-24.55 || média acao=-0.13
# Episodio 407: retorno=-13.01 || média acao=0.03
# Episodio 408: retorno=-12.29 || média acao=0.24
#
# D:  7.205506801605225    Sigma:  0.00012103781406198168
# Episodio 409: retorno=-0.55 || média acao=-0.23
# Episodio 410: retorno=-28.64 || média acao=-0.04
# Episodio 411: retorno=-0.2 || média acao=0.14
# Episodio 412: retorno=-12.3 || média acao=0.28
# Episodio 413: retorno=-26.92 || média acao=-0.07
#
# D:  6.453064918518066    Sigma:  0.00011003437641998334
# Episodio 414: retorno=-0.19 || média acao=-0.04
# Episodio 415: retorno=-0.16 || média acao=0.05
# Episodio 416: retorno=-12.79 || média acao=0.11
# Episodio 417: retorno=-12.65 || média acao=-0.23
# Episodio 418: retorno=-12.75 || média acao=0.17
#
# D:  7.032244682312012    Sigma:  0.00010003125129089394
# Episodio 419: retorno=-12.63 || média acao=-0.1
# Episodio 420: retorno=-12.91 || média acao=0.16
# Episodio 421: retorno=-12.47 || média acao=-0.11
# Episodio 422: retorno=-12.67 || média acao=-0.31
# Episodio 423: retorno=-13.39 || média acao=-0.61
#
# D:  6.327086448669434    Sigma:  9.093750117353994e-05
# Episodio 424: retorno=-12.59 || média acao=-0.68
# Episodio 425: retorno=-0.38 || média acao=-0.54
# Episodio 426: retorno=-24.84 || média acao=-0.28
# Episodio 427: retorno=-23.36 || média acao=-0.45
# Episodio 428: retorno=-30.76 || média acao=-0.22
#
# D:  6.242679595947266    Sigma:  8.267045561230902e-05
# Episodio 429: retorno=-13.19 || média acao=-0.34
# Episodio 430: retorno=-24.03 || média acao=-0.39
# Episodio 431: retorno=-13.24 || média acao=-0.34
# Episodio 432: retorno=-12.87 || média acao=-0.31
# Episodio 433: retorno=-22.99 || média acao=-0.23
#
# D:  7.003573894500732    Sigma:  7.515495964755365e-05
# Episodio 434: retorno=-24.18 || média acao=-0.19
# Episodio 435: retorno=-12.22 || média acao=-0.45
# Episodio 436: retorno=-12.01 || média acao=-0.07
# Episodio 437: retorno=-24.57 || média acao=-0.3
# Episodio 438: retorno=-23.93 || média acao=0.01
#
# D:  6.326328277587891    Sigma:  6.832269058868513e-05
# Episodio 439: retorno=-13.05 || média acao=-0.32
# Episodio 440: retorno=-0.22 || média acao=-0.25
# Episodio 441: retorno=-24.73 || média acao=-0.06
# Episodio 442: retorno=-12.47 || média acao=-0.32
# Episodio 443: retorno=-12.6 || média acao=-0.28
#
# D:  5.697565078735352    Sigma:  6.211153689880466e-05
# Episodio 444: retorno=-13.17 || média acao=-0.29
# Episodio 445: retorno=-12.68 || média acao=-0.27
# Episodio 446: retorno=-32.32 || média acao=-0.26
# Episodio 447: retorno=-0.13 || média acao=-0.39
# Episodio 448: retorno=-12.85 || média acao=-0.19
#
# D:  6.186298370361328    Sigma:  5.646503354436787e-05
# Episodio 449: retorno=-0.26 || média acao=-0.38
# Episodio 450: retorno=-12.85 || média acao=-0.4
# Episodio 451: retorno=-33.22 || média acao=-0.14
# Episodio 452: retorno=-12.27 || média acao=-0.15
# Episodio 453: retorno=-23.75 || média acao=-0.05
#
# D:  6.083499908447266    Sigma:  5.133184867669806e-05
# Episodio 454: retorno=-25.17 || média acao=-0.08
# Episodio 455: retorno=-12.48 || média acao=0.07
# Episodio 456: retorno=-39.17 || média acao=-0.19
# Episodio 457: retorno=-12.91 || média acao=-0.37
# Episodio 458: retorno=-13.07 || média acao=-0.7
#
# D:  7.559478282928467    Sigma:  4.666531697881641e-05
# Episodio 459: retorno=-13.46 || média acao=-0.72
# Episodio 460: retorno=-13.49 || média acao=-0.84
# Episodio 461: retorno=-12.98 || média acao=-1.23
# Episodio 462: retorno=-13.25 || média acao=-0.76
# Episodio 463: retorno=-12.47 || média acao=-1.13
#
# D:  6.260619640350342    Sigma:  4.242301543528764e-05
# Episodio 464: retorno=-28.55 || média acao=0.09
# Episodio 465: retorno=-12.75 || média acao=-0.35
# Episodio 466: retorno=-12.48 || média acao=-0.4
# Episodio 467: retorno=-12.86 || média acao=0.16
# Episodio 468: retorno=-12.23 || média acao=-0.29
#
# D:  6.271882057189941    Sigma:  3.856637766844331e-05
# Episodio 469: retorno=-23.39 || média acao=0.11
# Episodio 470: retorno=-25.53 || média acao=-0.27
# Episodio 471: retorno=-0.26 || média acao=-0.45
# Episodio 472: retorno=-0.21 || média acao=-0.45
# Episodio 473: retorno=-12.49 || média acao=-0.3
#
# D:  5.795452117919922    Sigma:  3.506034333494846e-05
# Episodio 474: retorno=-12.46 || média acao=-0.55
# Episodio 475: retorno=-24.54 || média acao=-0.62
# Episodio 476: retorno=-22.67 || média acao=-0.61
# Episodio 477: retorno=-23.14 || média acao=-0.37
# Episodio 478: retorno=-12.27 || média acao=-0.56
#
# D:  6.168786525726318    Sigma:  3.187303939540768e-05
# Episodio 479: retorno=-12.88 || média acao=-0.37
# Episodio 480: retorno=-13.0 || média acao=-0.4
# Episodio 481: retorno=-12.76 || média acao=-0.42
# Episodio 482: retorno=-12.11 || média acao=-0.59
# Episodio 483: retorno=-12.54 || média acao=-0.38
#
# D:  5.61461067199707    Sigma:  2.8975490359461528e-05
# Episodio 484: retorno=-33.88 || média acao=-0.37
# Episodio 485: retorno=-36.85 || média acao=-0.19
# Episodio 486: retorno=-12.55 || média acao=-0.33
# Episodio 487: retorno=-0.24 || média acao=-0.42
# Episodio 488: retorno=-12.94 || média acao=-0.39
#
# D:  4.765101432800293    Sigma:  2.634135487223775e-05
# Episodio 489: retorno=-13.48 || média acao=-0.25
# Episodio 490: retorno=-24.47 || média acao=-0.4
# Episodio 491: retorno=-23.35 || média acao=-0.3
# Episodio 492: retorno=-11.83 || média acao=-0.14
# Episodio 493: retorno=-0.34 || média acao=-0.37
#
# D:  4.905800819396973    Sigma:  2.3946686247488862e-05
# Episodio 494: retorno=-11.56 || média acao=-0.57
# Episodio 495: retorno=-12.18 || média acao=-0.22
# Episodio 496: retorno=-23.44 || média acao=-0.38
# Episodio 497: retorno=-23.79 || média acao=-0.09
# Episodio 498: retorno=-24.44 || média acao=-0.29
#
# D:  5.064068794250488    Sigma:  2.176971477044442e-05
# Episodio 499: retorno=-0.28 || média acao=-0.19
# Complete

# %%
plt.plot(list_retorno)
plt.title('Retorno por episódio')
plt.xlabel('Episódio')
plt.ylabel('Retorno')
plt.show()
